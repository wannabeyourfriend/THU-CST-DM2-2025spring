# %%
import matplotlib.pyplot as plt
import networkx as nx

from PT import *
process_table = {
    1: {'duration': 5, 'predecessors': []},
    2: {'duration': 8, 'predecessors': [1, 3]},
    3: {'duration': 3, 'predecessors': [1]},
    4: {'duration': 6, 'predecessors': [3]},
    5: {'duration': 10, 'predecessors': [2, 3]},
    6: {'duration': 4, 'predecessors': [2, 3]},
    7: {'duration': 8, 'predecessors': [3]},
    8: {'duration': 2, 'predecessors': [6, 7]},
    9: {'duration': 4, 'predecessors': [5, 8]},
    10: {'duration': 5, 'predecessors': [6, 7]}
}

# 创建PT图
pt = PT(process_table)
pt.print_process_table()
# 绘制图形
pt.draw()
pt.print_schedule_table()
# # 计算关键路径
# critical_info = pt.critical_path()
# print("关键路径节点:", critical_info['critical_nodes'])
# print("关键路径:", critical_info['critical_paths'])
# print("项目完成时间:", critical_info['completion_time'])

# # 计算各工序的允许延误时间
# delay_times = pt.delay()
# print("各工序的允许延误时间:")
# for process, delay in delay_times.items():
#     print(f"工序 {process}: {delay}")
# Out:
# ===== Computing Earliest Start Time and Latest Start Time =====
# Topological Order: 1 -> 3 -> 2 -> 4 -> 7 -> 5 -> 6 -> 8 -> 10 -> 9
#
# Initialize ES(i) = 0 for all i:
#   ES(1) = 0
#   ES(2) = 0
#   ES(3) = 0
#   ES(4) = 0
#   ES(5) = 0
#   ES(6) = 0
#   ES(7) = 0
#   ES(8) = 0
#   ES(9) = 0
#   ES(10) = 0
#
# Compute ES(j) = max{ES(i) + d(i) | i ∈ Pred(j)}:
#   Pred(1) = ∅, ES(1) = 0
#   Pred(3) = [1]
#   Calculation:
#     ES(3) ≥ ES(1) + d(1) = 0 + 5 = 5
#   ES(3) = max{...} = 5
#   Pred(2) = [1, 3]
#   Calculation:
#     ES(2) ≥ ES(1) + d(1) = 0 + 5 = 5
#     ES(2) ≥ ES(3) + d(3) = 5 + 3 = 8
#   ES(2) = max{...} = 8
#   Pred(4) = [3]
#   Calculation:
#     ES(4) ≥ ES(3) + d(3) = 5 + 3 = 8
#   ES(4) = max{...} = 8
#   Pred(7) = [3]
#   Calculation:
#     ES(7) ≥ ES(3) + d(3) = 5 + 3 = 8
#   ES(7) = max{...} = 8
#   Pred(5) = [2, 3]
#   Calculation:
#     ES(5) ≥ ES(2) + d(2) = 8 + 8 = 16
#     ES(5) ≥ ES(3) + d(3) = 5 + 3 = 8
#   ES(5) = max{...} = 16
#   Pred(6) = [2, 3]
# ...
